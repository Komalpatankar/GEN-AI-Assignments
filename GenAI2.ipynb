# %%
from transformers import pipeline

# %%
qa_pipeline = pipeline("text-generation", model="gpt2")

#Interview Approach
def interview_approach(question):
    return qa_pipeline(question)[0]['generated_text']

#Chain of Thought
def cot_prompting(question):
    prompt = f"Q: {question}\nLet's break it down step by step to find the answer."
    return qa_pipeline(prompt)[0]['generated_text']

#Tree of Thought
def tot_prompting(question):
    prompt = f"Q: {question}\nLet's consider multiple possible solutions and evaluate the best one."
    return qa_pipeline(prompt)[0]['generated_text']

#Zero-Shot vs. Few-Shot Prompting
def zero_shot(question):
    return qa_pipeline(question)[0]['generated_text']

def few_shot(question):
    examples = "Q: What is 12 + 15? A: 27\nQ: What is 8 * 3? A: 24\n"
    return qa_pipeline(examples + f"Q: {question}\nA:")[0]['generated_text']
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
test_question = "What is 25 + 37?"

# Running all approaches
print("Interview Approach:", interview_approach(test_question))
print("Chain of Thought:", cot_prompting(test_question))
print("Tree of Thought:", tot_prompting(test_question))
print("Zero-Shot:", zero_shot(test_question))
print("Few-Shot:", few_shot(test_question))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Interview Approach: What is 25 + 37? (20=25+35/37)
#
# It is interesting to compare the difference between the 2 versions of the 10th edition and the 4th edition, because each is in different ways: the 4th edition
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chain of Thought: Q: What is 25 + 37?
# Let's break it down step by step to find the answer.
# 1.1.1: The word '33' is not really that high, but it's not quite so low.
# Now
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Tree of Thought: Q: What is 25 + 37?
# Let's consider multiple possible solutions and evaluate the best one. A solution is that a 25 to 36 would be completely accurate. A solution would mean that with one of these two parameters we would have a total
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Zero-Shot: What is 25 + 37?
#
# There is a chance we still haven't fully established our definition. We're only able to define the word at certain points in time, and of course the definition is not up to our full understanding. There is
# Few-Shot: Q: What is 12 + 15? A: 27
# Q: What is 8 * 3? A: 24
# Q: What is 25 + 37?
# A: 25
# Q: What is 38 + 54*?
# A: 26
